# %% [markdown]
# Web data extraction

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('https://github.com/dipanjanS/text-analytics-with-python/raw/master/media/Womens%20Clothing%20E-Commerce%20Reviews%20-%20NLP.csv', keep_default_na=False)
df.head()
# Out:
#    Clothing ID  Age                    Title  \
# 0          767   33
# 1         1080   34
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# ...

# %%
df = pd.read_csv('C:/Users/rafik/Desktop/DataScience/Project/df_stock_mrkt_q.csv')
df.head()
# Out:
#    Unnamed: 0              key symbol                    companyName currency  \
# 0           0  OSUR_1988-12-31   OSUR     OraSure Technologies, Inc.      USD
# 1           1   CVM_1988-12-31    CVM            CEL-SCI Corporation      USD
# 2           2   UNF_1988-11-30    UNF           UniFirst Corporation      USD
# 3           3     J_1989-12-31      J  Jacobs Engineering Group Inc.      USD
# 4           4  MSFT_1989-12-31   MSFT          Microsoft Corporation      USD
#
#                   exchange exchangeShortName                        industry  \
# 0     NASDAQ Global Select            NASDAQ  Medical Instruments & Supplies
# 1  American Stock Exchange              AMEX                   Biotechnology
# 2  New York Stock Exchange              NYSE     Specialty Business Services
# 3  New York Stock Exchange              NYSE      Engineering & Construction
# 4     NASDAQ Global Select            NASDAQ         Software—Infrastructure
#
# ...

# %%
df.shape
# Out:
# (839749, 141)

# %%
df.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0              key symbol                    companyName  \
# 0                0  OSUR_1988-12-31   OSUR     OraSure Technologies, Inc.
# 1                1   CVM_1988-12-31    CVM            CEL-SCI Corporation
# 2                2   UNF_1988-11-30    UNF           UniFirst Corporation
# 3                3     J_1989-12-31      J  Jacobs Engineering Group Inc.
# 4                4  MSFT_1989-12-31   MSFT          Microsoft Corporation
# ...            ...              ...    ...                            ...
# 839744      903042   SYY_2022-01-01    SYY              Sysco Corporation
# 839745      903043   TSN_2022-01-01    TSN              Tyson Foods, Inc.
# 839746      903044   VFC_2022-01-01    VFC               V.F. Corporation
# 839747      903045  MASI_2022-01-01   MASI             Masimo Corporation
# 839748      903046  CRAI_2022-01-01   CRAI        CRA International, Inc.
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'key', 'symbol', 'companyName', 'currency', 'exchange',
#        'exchangeShortName', 'industry', 'sector', 'country',
#        ...
#        'cf_dividendsPaid', 'cf_otherFinancingActivites',
#        'cf_netCashUsedProvidedByFinancingActivities',
#        'cf_effectOfForexChangesOnCash', 'cf_netChangeInCash',
#        'cf_cashAtEndOfPeriod', 'cf_cashAtBeginningOfPeriod',
#        'cf_operatingCashFlow', 'cf_capitalExpenditure', 'cf_freeCashFlow'],
#       dtype='object', length=141)

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd

# %%
finviz_url = 'https://finviz.com/quote.ashx?t='

url = finviz_url + 'AMZN'
req = Request(url=url, headers={
    'User-Agent': 'Mozilla/5.0'
})
response = urlopen(req)
html = BeautifulSoup(response)
table = html.find(id='news-table')

# %%
table
# Out:
# <table border="0" cellpadding="1" cellspacing="0" class="fullview-news-outer" id="news-table" width="100%">
# <tr><td align="right" style="white-space:nowrap" width="130">Jul-07-22 08:11PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/gamestop-tumbles-cfo-firing-reports-212811227.html" target="_blank">GameStop Tumbles on CFOs Firing, Reports of Job Cuts</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# ...
